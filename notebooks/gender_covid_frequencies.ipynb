# %%
from covid.visualization.paper_freq import visualize_paper_freq
# Out:
# /Users/vasilis/Desktop/coronasucks/coronaBreakSuck2020/venv/lib/python3.7/site-packages/tqdm/std.py:658: FutureWarning: The Panel class is removed from pandas. Accessing it from the top-level namespace will also be removed in the next version
#   from pandas import Panel
# [nltk_data] Downloading package wordnet to /Users/vasilis/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %% [markdown]
# When we import ```visualize_paper_freq``` an instance of ```FrontPaperClassifier``` (YAML) is automatically created.

# %%
DATA_DIR = "../data/"
FILE_PATH = "processed/metadata_pre_proc.csv"

# %%
file_paths = [DATA_DIR + FILE_PATH] # file paths of pre-processed data, including date cols
subclass = 'gender'

# %%
visualize_paper_freq(file_paths, subclass, from_year=2000)
# Out:
# 100%|██████████| 33524/33524 [00:27<00:00, 1215.50it/s]
# 100%|██████████| 33524/33524 [00:28<00:00, 1183.84it/s]
# Dropped papers with MISSING dates: 10696/44220
# Num of COVID papers that match GENDER: 299/33524
# No papers were found for years: [2000, 2002]
