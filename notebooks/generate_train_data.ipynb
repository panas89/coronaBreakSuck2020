# %%
import pandas as pd
import numpy as np

from covid.data.constants import *
from covid.models.query_model import regexQueryDf, PatternGenerator
from covid.models.paperclassifier.frontpaperclassifier import FrontPaperClassifier

# Instantiate FrontPaperClassifier; to be used for keywords retrieval
YAML_PATH = '../covid/models/paperclassifier/interest.yaml'
fpc = FrontPaperClassifier(km_path=YAML_PATH)
# Out:
# /Users/vasilis/Desktop/coronasucks/coronaBreakSuck2020/venv/lib/python3.7/site-packages/tqdm/std.py:658: FutureWarning: The Panel class is removed from pandas. Accessing it from the top-level namespace will also be removed in the next version
#   from pandas import Panel
# [nltk_data] Error loading wordnet: <urlopen error [Errno 8] nodename
# [nltk_data]     nor servname provided, or not known>

# %%
# Helper Functions

def generate_sample_df(df, n=50, from_year=2010):
    """Creates a randomized sample from df's rows, while (roughly) preserving the percentages 
    of the papers published in different years."""
    
    # select only papers published from/after input year
    df_train = df[~df.publish_time.isnull()]
    df_train = df_train[df_train.publish_time >= str(from_year)]
    df_train['year'] = df_train.publish_time.dt.year
    
    # create normalized weights for each year
    weights = df_train.groupby('year')['title'].apply(lambda g: round(g.count()/len(df_train),2))
    weights.iloc[-1] = 1 - weights[:-1].sum()
    year_to_weight = weights.to_dict()
    series_of_weights = df_train.year.map(year_to_weight)
    
    # create sample
    df_sample = df_train.sample(n=n, weights=series_of_weights, random_state=100)
    
    return df_sample 


def save_as_doccano_txt(df, col, file_path):
    
    with open(file_path, "w") as f:
        f.write(" ".join([text+'\n' for text in list(df[col].values)]))
        
    print(f"Sample data saved as: {file_path}")
    
    return

# %% [markdown]
# # Import Raw Metadata

# %%
DATA_DIR = "../data/"
FILE_PATH = "raw/metadata.csv"
USECOLS = ['cord_uid', 'title', 'abstract', 'publish_time']

# %%
df = pd.read_csv(DATA_DIR + FILE_PATH, usecols=USECOLS, parse_dates=['publish_time'])
df.shape
# Out:
# (51078, 4)

# %% [markdown]
# # Filter data

# %%
cp = PatternGenerator(words=['SARS-CoV-2', 'covid','coronavirus', 'covid-19'])
cp.generatePattern()

rp = PatternGenerator(words=fpc.get_keywords('gender'))
rp.generatePattern()

patterns = [rp.getPattern(),cp.getPattern()]

# %%
cond = regexQueryDf(df, ['abstract'], patterns, operatorColumn='OR', operatorPattern='AND')
# Out:
# 100%|██████████| 51078/51078 [00:38<00:00, 1339.25it/s]
# 100%|██████████| 51078/51078 [00:36<00:00, 1411.45it/s]

# %%
df_filtered = df[cond]
df_filtered.shape
# Out:
# (402, 4)

# %% [markdown]
# # Create Sample

# %%
df_sample = generate_sample_df(df_filtered, n=50, from_year=2010)

# %%
df_sample.head()
# Out:
#        cord_uid                                              title  \
# 33179  xsgxd5sy  Clinical Characteristics of 74 Children with C...
# 32774  v0ln3wfa  Clinical Features of COVID-19 Related Liver Da...
# 32952  ohba2n2o  Clinical outcomes of 402 patients with COVID-2...
# 37469  p3g9nyl6  Laboratory Parameters in Detection of COVID-19...
# 4533   sc2j2os0  Alterations in Nerve-Evoked Bladder Contractio...
#
#                                                 abstract publish_time  year
# 33179  Background: Severe acute respiratory syndrome ...   2020-03-23  2020
# 32774  BACKGROUND: A recent outbreak of SARS-CoV-2 in...   2020-02-27  2020
# 32952  The SARS-CoV-2 outbreak is causing widespread ...   2020-03-10  2020
# 37469  INTRODUCTION: The role of laboratory parameter...   2020-04-04  2020
# 4533   BACKGROUND: Patients with neurodegenerative di...   2014-10-13  2014

# %% [markdown]
# # Export as txt

# %%
save_as_doccano_txt(df_sample, 
                    col='abstract', 
                    file_path = DATA_DIR + 'doccano_metadata.txt')
# Out:
# Sample data saved as: ../data/doccano_metadata.txt

# %% [markdown]
# # Read Annotated Sample

# %%
def read_doccano_json(file_path, label_to_name):
    
    df = pd.read_json(file_path, lines=True)
    
    # create label_name cols
    for name in label_to_name.values():
        df[name] = np.NaN
    
    # iterate over rows
    for i in range(len(df)):
        # iterate over labels (list of dicts)
        for d in df.loc[i,'annotations']:
            # update label value
            col = label_to_name[d['label']]
            df.loc[i,col] = df.loc[i,'text'][d['start_offset']: d['end_offset']]
    
    cols_to_drop = ['id', 'annotations']
    
    return df.rename({'text': 'abstract'}, axis=1)\
             .drop(cols_to_drop, axis=1)

# %%
label_to_name = {0:'target', 1:'target', 2:'target', 4:'o', 5:'c'}

# %%
read_doccano_json(DATA_DIR+'file.json', label_to_name)
# Out:
#                                              abstract meta  \
# 0   Objectives: Comorbidities have significant ind...   {}
# 1   OBJECTIVES: This study aimed to assess the aff...   {}
# 2   Background: Super-spreading events were associ...   {}
# 3   Objective: To evaluate the spectrum of comorbi...   {}
# 4   Background A novel coronavirus (SARA-CoV-2) em...   {}
# 5   INTRODUCTION: The role of laboratory parameter...   {}
# 6   Based on publicly released data for 1212 patie...   {}
# 7   BACKGROUND: Viral pathogens were more commonly...   {}
# 8   Background Chest CT is used to assess the seve...   {}
# 9   Objective To determine the correlation between...   {}
# 10  In response to the recent novel coronavirus ou...   {}
# 11  Abstract In December 2019, a coronavirus 2019 ...   {}
# 12  Aims: Studies have indicated that chloroquine ...   {}
# 13  Tang JW, et al. and colleagues have written to...   {}
# 14  Background Since late December, 2019, an outbr...   {}
# 15  AbstractA novel coronavirus (2019-nCov) was id...   {}
# 16  Previous studies on the pneumonia outbreak cau...   {}
# 17  Background: Information on kidney impairment i...   {}
# 18  SARS, in 2003, spread both within a geographic...   {}
# 19  The development of molecular syndrome-based ki...   {}
# 20  Abstract It is an ugly fact that a significant...   {}
# 21  To help health workers and the public recogniz...   {}
# 22  Motivation: Wuhan pneumonia is an acute infect...   {}
# 23  The SARS-CoV-2 outbreak is causing widespread ...   {}
# 24  Policies and public health efforts have not ad...   {}
# 25  BACKGROUND: To study the clinical data, discha...   {}
# 26  Background：In January 19, 2020, first case of ...   {}
# 27  BACKGROUND We described the epidemiological fe...   {}
# 28  The first known cases of Middle East respirato...   {}
# 29  Background Recent studies have focused initial...   {}
# 30  OBJECTIVE: The COVID-19 pandemic has caused mu...   {}
# 31  BACKGROUND. Human coronaviruses (CoV) have bee...   {}
# 32  Background & Aims The coronavirus disease 2019...   {}
# 33  As of March 20, 2020, there were 234,073 confi...   {}
# 34  Background: Since mid-December 2019, a cluster...   {}
# 35  Introduction. Middle East respiratory syndrome...   {}
# 36  WHO's Eastern Mediterranean region (EMR) is fa...   {}
# 37  This century is witnessing dramatic changes in...   {}
# 38  In the recent outbreak of COVID-19, many count...   {}
# 39  Background The 2019 novel coronavirus disease ...   {}
# 40  AIM AND OBJECTIVE: This study aims to evaluate...   {}
# 41  Objective: To assess the characteristics of co...   {}
# 42  Purpose: The aim of this study was to identify...   {}
# 43  To the Editor. An outbreak of coronavirus dise...   {}
# 44  Abstract Objectives Following the public-healt...   {}
# 45  Background Rapid spread of SARS-CoV-2 in Wuhan...   {}
# 46  Objective: To investigate the clinical present...   {}
# 47  Rationale: In late December 2019, an outbreak ...   {}
# 48  Background: The outbreak of coronavirus diseas...   {}
# 49  Abstract MERS-coronavirus infection is current...   {}
#
#     annotation_approver  target  \
# 0                   NaN     NaN
# 1                   NaN     NaN
# 2                   NaN     NaN
# 3                   NaN     NaN
# 4                   NaN     NaN
# 5                   NaN     NaN
# 6                   NaN     NaN
# 7                   NaN     NaN
# 8                   NaN     NaN
# 9                   NaN     NaN
# 10                  NaN     NaN
# 11                  NaN     NaN
# 12                  NaN     NaN
# 13                  NaN     NaN
# 14                  NaN     NaN
# 15                  NaN     NaN
# 16                  NaN     NaN
# 17                  NaN     NaN
# 18                  NaN     NaN
# 19                  NaN     NaN
# 20                  NaN     NaN
# 21                  NaN     NaN
# 22                  NaN     NaN
# 23                  NaN     NaN
# 24                  NaN     NaN
# 25                  NaN     NaN
# 26                  NaN     NaN
# 27                  NaN     NaN
# 28                  NaN     NaN
# 29                  NaN     NaN
# 30                  NaN     NaN
# 31                  NaN     NaN
# 32                  NaN     NaN
# 33                  NaN     NaN
# 34                  NaN     NaN
# 35                  NaN     NaN
# 36                  NaN     NaN
# 37                  NaN     NaN
# 38                  NaN     NaN
# 39                  NaN     NaN
# 40                  NaN     NaN
# 41                  NaN     NaN
# 42                  NaN     NaN
# 43                  NaN     NaN
# 44                  NaN     NaN
# 45                  NaN     NaN
# 46                  NaN     NaN
# 47                  NaN     NaN
# 48                  NaN     NaN
# 49                  NaN     NaN
#
#                                                     o  \
# 0                                                 NaN
# 1                                                 NaN
# 2   Super-spreading events were associated with th...
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
# 30                                                NaN
# 31                                                NaN
# 32                                                NaN
# 33                                                NaN
# 34                                                NaN
# 35                                                NaN
# 36                                                NaN
# 37                                                NaN
# 38                                                NaN
# 39                                                NaN
# 40                                                NaN
# 41                                                NaN
# 42                                                NaN
# 43                                                NaN
# 44                                                NaN
# 45                                                NaN
# 46                                                NaN
# 47                                                NaN
# 48                                                NaN
# 49                                                NaN
#
#                                                     c
# 0                                                 NaN
# 1                                                 NaN
# 2   The super-spreading events were associated wit...
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
# 30                                                NaN
# 31                                                NaN
# 32                                                NaN
# 33                                                NaN
# 34                                                NaN
# 35                                                NaN
# 36                                                NaN
# 37                                                NaN
# 38                                                NaN
# 39                                                NaN
# 40                                                NaN
# 41                                                NaN
# 42                                                NaN
# 43                                                NaN
# 44                                                NaN
# 45                                                NaN
# 46                                                NaN
# 47                                                NaN
# 48                                                NaN
# 49                                                NaN
